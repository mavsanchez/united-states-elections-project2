# %%
import pandas as pd
import numpy as np
import plotly

# %%
election_df = pd.read_csv("1976-2016-president.csv")

# %%
election_df.head()
# Out:
#    year    state state_po  state_fips  state_cen  state_ic        office  \
# 0  1976  Alabama       AL           1         63        41  US President
# 1  1976  Alabama       AL           1         63        41  US President
# 2  1976  Alabama       AL           1         63        41  US President
# 3  1976  Alabama       AL           1         63        41  US President
# 4  1976  Alabama       AL           1         63        41  US President
#
#                  candidate                       party  writein  \
# 0            Carter, Jimmy                    democrat    False
# 1             Ford, Gerald                  republican    False
# 2           Maddox, Lester  american independent party    False
# 3  Bubar, Benjamin ""Ben""                 prohibition    False
# 4                Hall, Gus         communist party use    False
#
#    candidatevotes  totalvotes   version  notes
# 0          659170     1182850  20171015    NaN
# ...

# %%
cleanestelection_df = election_df.query('party == "democrat" | party == "republican"')
cleanestelection_df
# Out:
# Empty DataFrame
# Columns: [year, state, state_po, state_fips, state_cen, state_ic, office, candidate, party, writein, candidatevotes, totalvotes, version, notes]
# Index: []

# %%
dem_electiondf = election_df[election_df['party'].isin(['democrat']) ]
rep_electiondf = election_df[election_df['party'].isin(['republican']) ]

combined_electiondf = pd.merge(dem_electiondf, rep_electiondf,  on =['state', 'year']) 
combined_electiondf.head(50)
# Out:
# Empty DataFrame
# Columns: [state_po_x, state_fips_x, state_cen_x, state_ic_x, office_x, candidate_x, party_x, writein_x, candidatevotes_x, totalvotes_x, version_x, notes_x, year, state, state_po_y, state_fips_y, state_cen_y, state_ic_y, office_y, candidate_y, party_y, writein_y, candidatevotes_y, totalvotes_y, version_y, notes_y]
# Index: []
#
# [0 rows x 26 columns]

# %%
cleanelection_df = combined_electiondf.drop_duplicates(subset= ['year_x', 'state'])
cleanelection_df
# Out:
#       year_x    state state_po_x  state_fips_x  state_cen_x  state_ic_x  \
# 0       1976  Alabama         AL             1           63          41
# 11      1980  Alabama         AL             1           63          41
# 22      1984  Alabama         AL             1           63          41
# 33      1988  Alabama         AL             1           63          41
# 44      1992  Alabama         AL             1           63          41
# ...      ...      ...        ...           ...          ...         ...
# 6129    2000  Wyoming         WY            56           83          68
# 6140    2004  Wyoming         WY            56           83          68
# 6151    2008  Wyoming         WY            56           83          68
# 6162    2012  Wyoming         WY            56           83          68
# 6173    2016  Wyoming         WY            56           83          68
#
#           office_x       candidate_x   party_x  writein_x  ...  state_cen_y  \
# ...

# %%
# Out:
#       year_x    state state_po_x  state_fips_x  state_cen_x  state_ic_x  \
# 0       1976  Alabama         AL             1           63          41
# 11      1980  Alabama         AL             1           63          41
# 33      1988  Alabama         AL             1           63          41
# 44      1992  Alabama         AL             1           63          41
# 55      1996  Alabama         AL             1           63          41
# ...      ...      ...        ...           ...          ...         ...
# 6074    1980  Wyoming         WY            56           83          68
# 6096    1988  Wyoming         WY            56           83          68
# 6107    1992  Wyoming         WY            56           83          68
# 6118    1996  Wyoming         WY            56           83          68
# 6173    2016  Wyoming         WY            56           83          68
#
#           office_x       candidate_x   party_x  writein_x  ...      office_y  \
# ...

# %%
cleanelection_df['winner1'] = np.where(cleanelection_df['candidate_y'] > cleanelection_df['candidate_x'], 'red', 'blue')
# Out:
# ---------------------------------------------------------------------------
# SettingWithCopyError                      Traceback (most recent call last)
# <ipython-input-75-ff5b1b3d90ca> in <module>
#       1 pd.set_option('chained_assignment','raise')
# ----> 2 cleanelection_df['winner1'] = np.where(cleanelection_df['candidate_y'] > cleanelection_df['candidate_x'], 'red', 'blue')
#
# ~\Anaconda34\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# ~\Anaconda34\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3554         # value exception to occur first
#    3555         if len(self):
# -> 3556             self._check_setitem_copy()
#    3557
#    3558     def insert(self, loc, column, value, allow_duplicates=False):
#
# ...

# %%
cleanelection_df
# Out:
#       year_x    state state_po_x  state_fips_x  state_cen_x  state_ic_x  \
# 0       1976  Alabama         AL             1           63          41
# 11      1980  Alabama         AL             1           63          41
# 22      1984  Alabama         AL             1           63          41
# 33      1988  Alabama         AL             1           63          41
# 44      1992  Alabama         AL             1           63          41
# ...      ...      ...        ...           ...          ...         ...
# 6129    2000  Wyoming         WY            56           83          68
# 6140    2004  Wyoming         WY            56           83          68
# 6151    2008  Wyoming         WY            56           83          68
# 6162    2012  Wyoming         WY            56           83          68
# 6173    2016  Wyoming         WY            56           83          68
#
#           office_x       candidate_x   party_x  writein_x  ...      office_y  \
# ...

# %%
df_1976 = cleanelection_df[cleanelection_df['year_x'].isin(['1976']) ]
# Out:
# 0                    Alabama
# 121                   Alaska
# 242                  Arizona
# 374                 Arkansas
# 495               California
# 616                 Colorado
# 737              Connecticut
# 858                 Delaware
# 979     District of Columbia
# 1100                 Florida
# 1221                 Georgia
# 1342                  Hawaii
# 1463                   Idaho
# 1584                Illinois
# 1705                 Indiana
# 1826                    Iowa
# 1947                  Kansas
# 2068                Kentucky
# 2189               Louisiana
# 2310                   Maine
# 2431                Maryland
# 2587           Massachusetts
# 2708                Michigan
# 2829               Minnesota
# 2917             Mississippi
# 3038                Missouri
# 3159                 Montana
# 3280                Nebraska
# 3401                  Nevada
# 3522           New Hampshire
# 3643              New Jersey
# 3764              New Mexico
# ...

# %%
data = dict(type = 'choropleth', 
  
            # location: Arizoana, California, Newyork 
            locations = df_1976['state'], 
              
            # States of USA 
            locationmode = 'USA-states', 
              
            # colorscale can be added as per requirement 
            colorscale = 'Portland', 
              
            # text can be given anything you like 
            text = ['text 1', 'text 2', 'text 3'], 
            z = [1.0, 2.0, 3.0], 
            colorbar = {'title': 'Colorbar Title Goes Here'}) 
              
layout = dict(geo ={'scope': 'usa'}) 
  
# passing data dictionary as a list  
choromap = go.Figure(data = [data], layout = layout) 
  
# plotting graph 
iplot(choromap)
