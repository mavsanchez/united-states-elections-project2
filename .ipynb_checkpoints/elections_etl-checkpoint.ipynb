# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os, string
import csv
import pymongo
import time
import json 
import numpy as np

# %% [markdown]
# # Extract (Scrape) Data
#
# #### *Does not need to be loaded to pymongo* - can be scraped on the spot for the Project 2

# %%
# currentDirectory = os.path.dirname(__file__)
# executable_path = {"executable_path": f"{currentDirectory}\chromedriver.exe"}
executable_path = {'executable_path': 'chromedriver.exe'} #notebook version
browser = Browser('chrome', **executable_path, headless=True)

# %% [markdown]
# ### Scrape Schedules

# %%
nba_sched_url = "https://www.espn.com/nba/schedule/_/date/"
browser.visit(nba_sched_url)
browser.html
html = browser.html
soup = BeautifulSoup(html, 'lxml')
sched_tables = soup.find('table', class_="schedule has-team-logos align-left")
schedules_sites = pd.read_html(sched_tables.prettify())
schedules_sites
# Out:
# [            matchup          Unnamed: 1 time  (PT) nat tv  \
#  0     Portland  POR        Indiana  IND       LIVE    TNT
#  1   Sacramento  SAC  Oklahoma City  OKC       LIVE    NaN
#  2  Los Angeles  LAL    Golden State  GS    7:30 PM    TNT
#
#                   tickets  Unnamed: 5
#  0     Buy on Vivid Seats         NaN
#  1     Buy on Vivid Seats         NaN
#  2  Tickets as low as $36         NaN  ]

# %% [markdown]
# # Load - Transform

# %% [markdown]
# ### Load dump to mongo / Clean on the go

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)
db = client.nba
# db.nba_players_stg.drop()
# db.nba_news_live.drop()

# %%
base_reference_url = "https://www.landofbasketball.com"
#Traverse to all players
for letter in string.ascii_lowercase[:26]:
    players_url = f"https://www.landofbasketball.com/nba_players_index/letter_{letter}.htm"
    browser.visit(players_url)
    browser.html
    html = browser.html
    soup = BeautifulSoup(html, 'lxml')
    all_player_table = soup.find_all('div', class_="indice-items")
    for row in all_player_table:
        player_d = {}
        print(row.find('a')['href'], end='')
        player_url = row.find('a')['href'].replace('..', base_reference_url)
        tables = pd.read_html(player_url)
        try_df = tables[1].set_index(0)
        try_df.rename(columns={0: "Key", 1: "Value"}, inplace=True)
        try_df = try_df.to_dict('index')
        player_d['Name'] = tables[3][0][0].split(' Profile',1)[0]
        player_d['Data'] = try_df
        db.nba_players_stg.insert_one(player_d)

# %% [markdown]
# ### Validate data availability

# %%
# result_dict['facts'] = list(db.mars_fact.find({}, {"_id": 0}))
for a in db.nba_players_stg.find({}, {"_id": 0}).limit(2):
    print(a)
# Out:
# {'Name': 'Alaa Abdelnaby', 'Data': {'Position:': {'Value': 'Forward / Center'}, 'Jersey Number:': {'Value': '31 (Trail Blazers), 5 (Bucks), 4 (Celtics), 30 (Kings, 76ers)'}, 'Height:': {'Value': '6-10 / 2.08 mts'}, 'Weight:': {'Value': '240 lbs / 108.9 kg'}, 'Born:': {'Value': 'June 24, 1968 in Cairo, Egypt'}, 'High-School:': {'Value': 'Bloomfield in Bloomfield, New Jersey'}, 'College:': {'Value': 'Duke University'}, 'Drafted:': {'Value': 'by the Portland Trail Blazers with No. 25 overall pick in round 1 of the 1990 NBA Draft'}, 'NBA Seasons:': {'Value': '5 (3 Playoffs)'}, 'NBA Titles:': {'Value': 'none'}, 'All-Star:': {'Value': 'none'}}}
# {'Name': 'Zaid Abdul-Aziz', 'Data': {'Position:': {'Value': 'Center / Forward'}, 'Jersey Number:': {'Value': '21 (Royals), 16 (Bucks), 35 (Bucks, Supersonics), 6 (Rockets), 35 (Rockets, Braves), 54 (Celtics), 27 (Rockets)'}, 'Height:': {'Value': '6-9 / 2.06 mts'}, 'Weight:': {'Value': '235 lbs / 106.6 kg'}, 'Born:': {'Value': 'April 07, 1946 in Brooklyn, New York, USA'}, 'High-School:': {'Value': 'John Jay in Brooklyn, New York'}, 'College:': {'Value': 'Iowa State University'}, 'Drafted:': {'Value': 'by the Cincinnati Royals with No. 5 overall pick in round 1 of the 1968 NBA Draft'}, 'NBA Seasons:': {'Value': '10 (3 Playoffs)'}, 'NBA Titles:': {'Value': 'none'}, 'All-Star:': {'Value': 'none'}}}

# %% [markdown]
# ## Scrape News

# %%
nba_news_url = "https://apnews.com/NBA"
browser.visit(nba_news_url)
browser.html
# time.sleep(10)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

news_tables = soup.find_all('div', attrs={"data-key":"feed-card-wire-story-with-image"})
# schedules_sites = pd.read_html(sched_tables.prettify())
# schedules_sites

# %%
for row in news_tables:
    news_content = {}
    news_content['headline'] = row.h1.text
    news_content['content'] = row.p.text
    print(f"Loading {row.h1.text}....")
    db.nba_news_live.insert_one(news_content)

# %% [markdown]
# ### ETL For elections

# %%
# geojson_source = "etl/gz_2010_us_050_00_500k.json"
# geojson_pd = pd.read_json(geojson_source)

# json_file = "etl/gz_2010_us_050_00_500k.json"
# customer_location_df = pd.read_json(json_file, encoding="utf-8")

# %%
results_file = "etl/countypres_2000-2016.csv"
results_df = pd.read_csv(results_file, encoding="utf-8")
results_df.head()
results_df.dropna(inplace=True)
results_df.drop(columns=['office', 'version'],inplace=True)
results_df.head()
# Out:
#    year    state state_po   county    FIPS       candidate       party  \
# 0  2000  Alabama       AL  Autauga  1001.0         Al Gore    democrat
# 1  2000  Alabama       AL  Autauga  1001.0  George W. Bush  republican
# 2  2000  Alabama       AL  Autauga  1001.0     Ralph Nader       green
# 4  2000  Alabama       AL  Baldwin  1003.0         Al Gore    democrat
# 5  2000  Alabama       AL  Baldwin  1003.0  George W. Bush  republican
#
#    candidatevotes  totalvotes
# 0          4942.0       17208
# 1         11993.0       17208
# 2           160.0       17208
# 4         13997.0       56480
# 5         40872.0       56480

# %%
# results_df.loc[results_df['county'].str.lower() =="Orange".lower(),:]

# Cast float to integer
results_df.FIPS = results_df.FIPS.astype(int)
results_df.candidatevotes = results_df.candidatevotes.astype(int)
results_df.party = results_df.party.str.title()
# Calculate percent won
results_df["percentwon"] = ((results_df.candidatevotes / results_df.totalvotes) * 100).map("{0:,.2f}".format).astype(float)
# results_df.percentwon = results_df.percentwon.astype(int)
# Drop index
results_df.reset_index(drop=True, inplace=True)

# Test results
# results_df.loc[(results_df['county'].str.lower() =="Orange".lower()) & (results_df['state'] == "California"),:].head(100)
# results_df.head()
# results_2016 = results_df.loc[(results_df.year == 2016) & (results_df['state'] == "California"),:]
#results_2016 = results_df.loc[(results_df.year >= 2008) & (results_df.year <= 2016) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]

# %%
results_2016
# Out:
#        year    state state_po       county  FIPS        candidate       party  \
# 15293  2008  Alabama       AL      Autauga  1001     Barack Obama    Democrat
# 15294  2008  Alabama       AL      Autauga  1001      John McCain  Republican
# 15295  2008  Alabama       AL      Baldwin  1003     Barack Obama    Democrat
# 15296  2008  Alabama       AL      Baldwin  1003      John McCain  Republican
# 15297  2008  Alabama       AL      Barbour  1005     Barack Obama    Democrat
# ...     ...      ...      ...          ...   ...              ...         ...
# 34410  2016   Alaska       AK  District 38  2038     Donald Trump  Republican
# 34411  2016   Alaska       AK  District 39  2039  Hillary Clinton    Democrat
# 34412  2016   Alaska       AK  District 39  2039     Donald Trump  Republican
# 34413  2016   Alaska       AK  District 40  2040  Hillary Clinton    Democrat
# 34414  2016   Alaska       AK  District 40  2040     Donald Trump  Republican
#
#        candidatevotes  totalvotes  percentwon
# 15293            6093       23641       25.77
# 15294           17403       23641       73.61
# 15295           19386       81413       23.81
# 15296           61271       81413       75.26
# 15297            5697       11630       48.99
# ...               ...         ...         ...
# 34410            1143        5095       22.43
# 34411            3142        5639       55.72
# 34412            1405        5639       24.92
# 34413            2338        4610       50.72
# 34414            1377        4610       29.87
#
# [18922 rows x 10 columns]

# %%
# results_df.to_json("etl/processed.json", orient='records')

# %% [markdown]
# ## GEO JSON BIG SOURCE

# %%
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html
# geojson_source = "etl/us-county-boundaries.geojson" https://public.opendatasoft.com/explore/dataset/us-county-boundaries/export/?refine.stusab=CA
# geojson_source = "etl/gz_2010_us_050_00_500k.json"
# geojson_source = "etl/ca-us-county-boundaries.csv.csv"
geojson_source = "etl/us-county-boundaries.csv"
geojson_pd = pd.read_csv(geojson_source, delimiter=';')
geojson_pd.dtypes
geojson_pd = geojson_pd[['GEOID','Geo Shape']]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-4e5bbbfa9539> in <module>
#       4 # geojson_source = "etl/ca-us-county-boundaries.csv.csv"
#       5 geojson_source = "etl/us-county-boundaries.csv"
# ----> 6 geojson_pd = pd.read_csv(geojson_source, delimiter=';')
#       7 geojson_pd.dtypes
#       8 geojson_pd = geojson_pd[['GEOID','Geo Shape']]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File etl/us-county-boundaries.csv does not exist: 'etl/us-county-boundaries.csv'

# %% [markdown]
# ### GEOJSON Small source

# %%
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html
# geojson_source = "etl/us-county-boundaries.geojson" https://public.opendatasoft.com/explore/dataset/us-county-boundaries/export/?refine.stusab=CA
# geojson_source = "etl/gz_2010_us_050_00_500k.json"
# geojson_source = "etl/ca-us-county-boundaries.csv.csv"
geojson_source = "etl/gz_2010_us_050_00_20m.json"
geojson_pd = pd.read_json(geojson_source, encoding='latin-1', lines=True)
geojson_pd.rename(columns={"geometry": "Geo Shape"},inplace=True)
# geojson_pd = geojson_pd[['Geometry']]
# geojson_pd['FIPS'] = int(geojson_pd['properties']['GEO_ID'][-5:])
geojson_pd['GEOID']  = geojson_pd.apply(lambda row: int(row.properties['GEO_ID'][-5:]), axis=1)
# geojson_pd['properties'][0]['GEO_ID'] '0500000US01001'
# int(geojson_pd['properties'][0]['GEO_ID'][-5:])
# geojson_pd

# %%
geojson_pd.head(10)
# Out:
#                                           properties  \
# 0  {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 1  {'GEO_ID': '0500000US01009', 'STATE': '01', 'C...
# 2  {'GEO_ID': '0500000US01017', 'STATE': '01', 'C...
# 3  {'GEO_ID': '0500000US01021', 'STATE': '01', 'C...
# 4  {'GEO_ID': '0500000US01033', 'STATE': '01', 'C...
# 5  {'GEO_ID': '0500000US01045', 'STATE': '01', 'C...
# 6  {'GEO_ID': '0500000US01051', 'STATE': '01', 'C...
# 7  {'GEO_ID': '0500000US01065', 'STATE': '01', 'C...
# 8  {'GEO_ID': '0500000US01079', 'STATE': '01', 'C...
# 9  {'GEO_ID': '0500000US01083', 'STATE': '01', 'C...
#
#                                            Geo Shape  GEOID
# 0  {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001
# 1  {'type': 'Polygon', 'coordinates': [[[-86.5777...   1009
# 2  {'type': 'Polygon', 'coordinates': [[[-85.1841...   1017
# 3  {'type': 'Polygon', 'coordinates': [[[-86.5173...   1021
# 4  {'type': 'Polygon', 'coordinates': [[[-88.1399...   1033
# 5  {'type': 'Polygon', 'coordinates': [[[-85.4164...   1045
# 6  {'type': 'Polygon', 'coordinates': [[[-86.3367...   1051
# 7  {'type': 'Polygon', 'coordinates': [[[-87.4212...   1065
# 8  {'type': 'Polygon', 'coordinates': [[[-87.1050...   1079
# 9  {'type': 'Polygon', 'coordinates': [[[-86.8363...   1083

# %%
# geojson_pd
# results_df
def geo_merger(results_2016):
    joined_df = pd.DataFrame();
    joined_df = geojson_pd.merge(results_2016[['FIPS','year','state_po','county','candidate','party','candidatevotes','totalvotes','percentwon']].loc[(results_2016.party == 'Republican')], how="inner", right_on='FIPS', left_on='GEOID');
    joined_df = joined_df.merge(results_2016[['FIPS','candidate','party','candidatevotes','totalvotes','percentwon']].loc[(results_2016.party == 'Democrat')], how="inner", right_on='FIPS', left_on='GEOID',suffixes=('_rep', '_dem'));
    joined_df['winner'] = np.where(joined_df['candidatevotes_rep'] > joined_df['candidatevotes_dem'], 'red',  'blue');
    return joined_df;

# %%
results_2008 = results_df.loc[(results_df.year == 2008) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]
results_2012 = results_df.loc[(results_df.year == 2012) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]
results_2016 = results_df.loc[(results_df.year == 2016) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]
merged_2008 = geo_merger(results_2008);
merged_2012 = geo_merger(results_2012);
merged_2016 = geo_merger(results_2016);

# %%
results_2008
# Out:
#                                              properties  \
# 0     {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 1     {'GEO_ID': '0500000US01009', 'STATE': '01', 'C...
# 2     {'GEO_ID': '0500000US01017', 'STATE': '01', 'C...
# 3     {'GEO_ID': '0500000US01021', 'STATE': '01', 'C...
# 4     {'GEO_ID': '0500000US01033', 'STATE': '01', 'C...
# ...                                                 ...
# 3111  {'GEO_ID': '0500000US51001', 'STATE': '51', 'C...
# 3112  {'GEO_ID': '0500000US51021', 'STATE': '51', 'C...
# 3113  {'GEO_ID': '0500000US51027', 'STATE': '51', 'C...
# 3114  {'GEO_ID': '0500000US51037', 'STATE': '51', 'C...
# 3115  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
#
#                                               Geo Shape  GEOID  FIPS_rep  \
# 0     {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001      1001
# 1     {'type': 'Polygon', 'coordinates': [[[-86.5777...   1009      1009
# 2     {'type': 'Polygon', 'coordinates': [[[-85.1841...   1017      1017
# 3     {'type': 'Polygon', 'coordinates': [[[-86.5173...   1021      1021
# 4     {'type': 'Polygon', 'coordinates': [[[-88.1399...   1033      1033
# ...                                                 ...    ...       ...
# 3111  {'type': 'MultiPolygon', 'coordinates': [[[[-7...  51001     51001
# 3112  {'type': 'Polygon', 'coordinates': [[[-81.2251...  51021     51021
# 3113  {'type': 'Polygon', 'coordinates': [[[-81.9682...  51027     51027
# 3114  {'type': 'Polygon', 'coordinates': [[[-78.4433...  51037     51037
# 3115  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041     51041
#
#       year state_po        county candidate_rep   party_rep  \
# 0     2008       AL       Autauga   John McCain  Republican
# 1     2008       AL        Blount   John McCain  Republican
# 2     2008       AL      Chambers   John McCain  Republican
# 3     2008       AL       Chilton   John McCain  Republican
# 4     2008       AL       Colbert   John McCain  Republican
# ...    ...      ...           ...           ...         ...
# 3111  2008       VA      Accomack   John McCain  Republican
# 3112  2008       VA         Bland   John McCain  Republican
# 3113  2008       VA      Buchanan   John McCain  Republican
# 3114  2008       VA     Charlotte   John McCain  Republican
# 3115  2008       VA  Chesterfield   John McCain  Republican
#
#       candidatevotes_rep  totalvotes_rep  percentwon_rep  FIPS_dem  \
# 0                  17403           23641           73.61      1001
# 1                  20389           24267           84.02      1009
# 2                   8067           14956           53.94      1017
# 3                  13960           17785           78.49      1021
# 4                  14739           24843           59.33      1033
# ...                  ...             ...             ...       ...
# 3111                7833           15623           50.14     51001
# 3112                2031            2959           68.64     51021
# 3113                4541            8734           51.99     51027
# 3114                3372            6157           54.77     51037
# 3115               86413          162088           53.31     51041
#
#      candidate_dem party_dem  candidatevotes_dem  totalvotes_dem  \
# 0     Barack Obama  Democrat                6093           23641
# 1     Barack Obama  Democrat                3522           24267
# 2     Barack Obama  Democrat                6799           14956
# 3     Barack Obama  Democrat                3674           17785
# 4     Barack Obama  Democrat                9703           24843
# ...            ...       ...                 ...             ...
# 3111  Barack Obama  Democrat                7607           15623
# 3112  Barack Obama  Democrat                 864            2959
# 3113  Barack Obama  Democrat                4063            8734
# 3114  Barack Obama  Democrat                2705            6157
# 3115  Barack Obama  Democrat               74310          162088
#
#       percentwon_dem winner
# 0              25.77    red
# 1              14.51    red
# 2              45.46    red
# 3              20.66    red
# 4              39.06    red
# ...              ...    ...
# 3111           48.69    red
# 3112           29.20    red
# 3113           46.52    red
# 3114           43.93    red
# 3115           45.85    red
#
# [3116 rows x 19 columns]

# %%
joined_df
# Out:
#                                               properties  \
# 0      {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 1      {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 2      {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 3      {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 4      {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# ...                                                  ...
# 28034  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
# 28035  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
# 28036  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
# 28037  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
# 28038  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
#
#                                                Geo Shape  GEOID  FIPS_rep  \
# 0      {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001      1001
# 1      {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001      1001
# 2      {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001      1001
# 3      {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001      1001
# 4      {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001      1001
# ...                                                  ...    ...       ...
# 28034  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041     51041
# 28035  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041     51041
# 28036  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041     51041
# 28037  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041     51041
# 28038  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041     51041
#
#        year state_po        county candidate_rep   party_rep  \
# 0      2008       AL       Autauga   John McCain  Republican
# 1      2008       AL       Autauga   John McCain  Republican
# 2      2008       AL       Autauga   John McCain  Republican
# 3      2012       AL       Autauga   Mitt Romney  Republican
# 4      2012       AL       Autauga   Mitt Romney  Republican
# ...     ...      ...           ...           ...         ...
# 28034  2012       VA  Chesterfield   Mitt Romney  Republican
# 28035  2012       VA  Chesterfield   Mitt Romney  Republican
# 28036  2016       VA  Chesterfield  Donald Trump  Republican
# 28037  2016       VA  Chesterfield  Donald Trump  Republican
# 28038  2016       VA  Chesterfield  Donald Trump  Republican
#
#        candidatevotes_rep  totalvotes_rep  percentwon_rep  FIPS_dem  \
# 0                   17403           23641           73.61      1001
# 1                   17403           23641           73.61      1001
# 2                   17403           23641           73.61      1001
# 3                   17379           23932           72.62      1001
# 4                   17379           23932           72.62      1001
# ...                   ...             ...             ...       ...
# 28034               90934          170988           53.18     51041
# 28035               90934          170988           53.18     51041
# 28036               85045          176461           48.19     51041
# 28037               85045          176461           48.19     51041
# 28038               85045          176461           48.19     51041
#
#          candidate_dem party_dem  candidatevotes_dem  totalvotes_dem  \
# 0         Barack Obama  Democrat                6093           23641
# 1         Barack Obama  Democrat                6363           23932
# 2      Hillary Clinton  Democrat                5936           24973
# 3         Barack Obama  Democrat                6093           23641
# 4         Barack Obama  Democrat                6363           23932
# ...                ...       ...                 ...             ...
# 28034     Barack Obama  Democrat               77694          170988
# 28035  Hillary Clinton  Democrat               81074          176461
# 28036     Barack Obama  Democrat               74310          162088
# 28037     Barack Obama  Democrat               77694          170988
# 28038  Hillary Clinton  Democrat               81074          176461
#
#        percentwon_dem winner
# 0               25.77    red
# 1               26.59    red
# 2               23.77    red
# 3               25.77    red
# 4               26.59    red
# ...               ...    ...
# 28034           45.44    red
# 28035           45.94    red
# 28036           45.85    red
# 28037           45.44    red
# 28038           45.94    red
#
# [28039 rows x 19 columns]

# %%
def df_to_geojson(df, properties):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{}
#                    'geometry':{}
                  }
        feature['geometry'] = row['Geo Shape'] #Use json.loads(row['Geo Shape']) if using the big source
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
# properties = ['year', 'state_po', 'county', 'candidate_rep', 'party_rep', 'candidatevotes_rep', 'percentwon_rep', 'candidate_dem', 'party_dem', 'candidatevotes_dem', 'totalvotes_dem', 'percentwon_dem', 'winner']
properties = ['state_po', 'county', 'candidate_rep', 'party_rep', 'candidatevotes_rep', 'percentwon_rep', 'candidate_dem', 'party_dem', 'candidatevotes_dem', 'totalvotes_dem', 'percentwon_dem', 'winner']
geojson = df_to_geojson(joined_df, properties)

# %%
json = json.dumps(geojson)
f = open("etl/processed.json","w")
f.write(json)
f.close()

# output_filename = 'dataset.js'
# with open(output_filename, 'wb') as output_file:
#     output_file.write('var dataset = ')
#     json.dump(geojson, output_file, indent=2)

# %%
geojson_pd
# Out:
#                                              properties  \
# 0     {'GEO_ID': '0500000US01001', 'STATE': '01', 'C...
# 1     {'GEO_ID': '0500000US01009', 'STATE': '01', 'C...
# 2     {'GEO_ID': '0500000US01017', 'STATE': '01', 'C...
# 3     {'GEO_ID': '0500000US01021', 'STATE': '01', 'C...
# 4     {'GEO_ID': '0500000US01033', 'STATE': '01', 'C...
# ...                                                 ...
# 3216  {'GEO_ID': '0500000US51001', 'STATE': '51', 'C...
# 3217  {'GEO_ID': '0500000US51021', 'STATE': '51', 'C...
# 3218  {'GEO_ID': '0500000US51027', 'STATE': '51', 'C...
# 3219  {'GEO_ID': '0500000US51037', 'STATE': '51', 'C...
# 3220  {'GEO_ID': '0500000US51041', 'STATE': '51', 'C...
#
#                                                geometry   FIPS
# 0     {'type': 'Polygon', 'coordinates': [[[-86.4967...   1001
# 1     {'type': 'Polygon', 'coordinates': [[[-86.5777...   1009
# 2     {'type': 'Polygon', 'coordinates': [[[-85.1841...   1017
# 3     {'type': 'Polygon', 'coordinates': [[[-86.5173...   1021
# 4     {'type': 'Polygon', 'coordinates': [[[-88.1399...   1033
# ...                                                 ...    ...
# 3216  {'type': 'MultiPolygon', 'coordinates': [[[[-7...  51001
# 3217  {'type': 'Polygon', 'coordinates': [[[-81.2251...  51021
# 3218  {'type': 'Polygon', 'coordinates': [[[-81.9682...  51027
# 3219  {'type': 'Polygon', 'coordinates': [[[-78.4433...  51037
# 3220  {'type': 'Polygon', 'coordinates': [[[-77.8518...  51041
#
# [3221 rows x 3 columns]
