# %%
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os, string
import csv
import pymongo
import time
import json 
import numpy as np

# %% [markdown]
# # Extract (Scrape) Data
#
# #### *Does not need to be loaded to pymongo* - can be scraped on the spot for the Project 2

# %%
# currentDirectory = os.path.dirname(__file__)
# executable_path = {"executable_path": f"{currentDirectory}\chromedriver.exe"}
executable_path = {'executable_path': 'chromedriver.exe'} #notebook version
browser = Browser('chrome', **executable_path, headless=True)

# %% [markdown]
# ### Scrape Schedules

# %%
nba_sched_url = "https://www.espn.com/nba/schedule/_/date/"
browser.visit(nba_sched_url)
browser.html
html = browser.html
soup = BeautifulSoup(html, 'lxml')
sched_tables = soup.find('table', class_="schedule has-team-logos align-left")
schedules_sites = pd.read_html(sched_tables.prettify())
schedules_sites

# %% [markdown]
# # Load - Transform

# %% [markdown]
# ### Load dump to mongo / Clean on the go

# %%
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)
db = client.nba
# db.nba_players_stg.drop()
# db.nba_news_live.drop()

# %%
base_reference_url = "https://www.landofbasketball.com"
#Traverse to all players
for letter in string.ascii_lowercase[:26]:
    players_url = f"https://www.landofbasketball.com/nba_players_index/letter_{letter}.htm"
    browser.visit(players_url)
    browser.html
    html = browser.html
    soup = BeautifulSoup(html, 'lxml')
    all_player_table = soup.find_all('div', class_="indice-items")
    for row in all_player_table:
        player_d = {}
        print(row.find('a')['href'], end='')
        player_url = row.find('a')['href'].replace('..', base_reference_url)
        tables = pd.read_html(player_url)
        try_df = tables[1].set_index(0)
        try_df.rename(columns={0: "Key", 1: "Value"}, inplace=True)
        try_df = try_df.to_dict('index')
        player_d['Name'] = tables[3][0][0].split(' Profile',1)[0]
        player_d['Data'] = try_df
        db.nba_players_stg.insert_one(player_d)

# %% [markdown]
# ### Validate data availability

# %%
# result_dict['facts'] = list(db.mars_fact.find({}, {"_id": 0}))
for a in db.nba_players_stg.find({}, {"_id": 0}).limit(2):
    print(a)

# %% [markdown]
# ## Scrape News

# %%
nba_news_url = "https://apnews.com/NBA"
browser.visit(nba_news_url)
browser.html
# time.sleep(10)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

news_tables = soup.find_all('div', attrs={"data-key":"feed-card-wire-story-with-image"})
# schedules_sites = pd.read_html(sched_tables.prettify())
# schedules_sites

# %%
for row in news_tables:
    news_content = {}
    news_content['headline'] = row.h1.text
    news_content['content'] = row.p.text
    print(f"Loading {row.h1.text}....")
    db.nba_news_live.insert_one(news_content)

# %% [markdown]
# ### ETL For elections

# %%
# geojson_source = "etl/gz_2010_us_050_00_500k.json"
# geojson_pd = pd.read_json(geojson_source)

# json_file = "etl/gz_2010_us_050_00_500k.json"
# customer_location_df = pd.read_json(json_file, encoding="utf-8")

# %%
results_file = "etl/countypres_2000-2016.csv"
results_df = pd.read_csv(results_file, encoding="utf-8")
results_df.head()
results_df.dropna(inplace=True)
results_df.drop(columns=['office', 'version'],inplace=True)
results_df.head()

# %%
# results_df.loc[results_df['county'].str.lower() =="Orange".lower(),:]

# Cast float to integer
results_df.FIPS = results_df.FIPS.astype(int)
results_df.candidatevotes = results_df.candidatevotes.astype(int)
results_df.party = results_df.party.str.title()
# Calculate percent won
results_df["percentwon"] = ((results_df.candidatevotes / results_df.totalvotes) * 100).map("{0:,.2f}".format).astype(float)
# results_df.percentwon = results_df.percentwon.astype(int)
# Drop index
results_df.reset_index(drop=True, inplace=True)

# Test results
# results_df.loc[(results_df['county'].str.lower() =="Orange".lower()) & (results_df['state'] == "California"),:].head(100)
# results_df.head()
# results_2016 = results_df.loc[(results_df.year == 2016) & (results_df['state'] == "California"),:]
#results_2016 = results_df.loc[(results_df.year >= 2008) & (results_df.year <= 2016) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]

# %%
results_2016

# %%
# results_df.to_json("etl/processed.json", orient='records')

# %% [markdown]
# ## GEO JSON BIG SOURCE

# %%
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html
# geojson_source = "etl/us-county-boundaries.geojson" https://public.opendatasoft.com/explore/dataset/us-county-boundaries/export/?refine.stusab=CA
# geojson_source = "etl/gz_2010_us_050_00_500k.json"
# geojson_source = "etl/ca-us-county-boundaries.csv.csv"
geojson_source = "etl/us-county-boundaries.csv"
geojson_pd = pd.read_csv(geojson_source, delimiter=';')
geojson_pd.dtypes
geojson_pd = geojson_pd[['GEOID','Geo Shape']]

# %% [markdown]
# ### GEOJSON Small source

# %%
# https://www.census.gov/geographies/mapping-files/time-series/geo/carto-boundary-file.html
# geojson_source = "etl/us-county-boundaries.geojson" https://public.opendatasoft.com/explore/dataset/us-county-boundaries/export/?refine.stusab=CA
# geojson_source = "etl/gz_2010_us_050_00_500k.json"
# geojson_source = "etl/ca-us-county-boundaries.csv.csv"
geojson_source = "etl/gz_2010_us_050_00_20m.json"
geojson_pd = pd.read_json(geojson_source, encoding='latin-1', lines=True)
geojson_pd.rename(columns={"geometry": "Geo Shape", "GEO_ID": "geoid"},inplace=True)
# geojson_pd = geojson_pd[['Geometry']]
# geojson_pd['FIPS'] = int(geojson_pd['properties']['GEO_ID'][-5:])
geojson_pd['FIPS']  = geojson_pd.apply(lambda row: int(row.properties['GEO_ID'][-5:]), axis=1)
geojson_pd['STATEID']  = geojson_pd.apply(lambda row: int(row.properties['STATE']), axis=1)
geojson_pd['geoid']  = geojson_pd.apply(lambda row: row.properties['GEO_ID'], axis=1)
# geojson_pd['properties'][0]['GEO_ID'] '0500000US01001'
# int(geojson_pd['properties'][0]['GEO_ID'][-5:])
# geojson_pd

# %%
# geojson_source = "etl/us_states.json"
# geojson_pd = pd.read_json(geojson_source, lines=True)
# geojson_pd
california_geojson_pd = geojson_pd.loc[(geojson_pd.STATEID == 6),:].reset_index()
california_geojson_pd
# Out:
#     index                                         properties  \
# 0      23  {'GEO_ID': '0500000US06005', 'STATE': '06', 'C...
# 1      24  {'GEO_ID': '0500000US06021', 'STATE': '06', 'C...
# 2      25  {'GEO_ID': '0500000US06033', 'STATE': '06', 'C...
# 3      26  {'GEO_ID': '0500000US06043', 'STATE': '06', 'C...
# 4      27  {'GEO_ID': '0500000US06055', 'STATE': '06', 'C...
# 5      28  {'GEO_ID': '0500000US06089', 'STATE': '06', 'C...
# 6      29  {'GEO_ID': '0500000US06099', 'STATE': '06', 'C...
# 7      30  {'GEO_ID': '0500000US06115', 'STATE': '06', 'C...
# 8     684  {'GEO_ID': '0500000US06003', 'STATE': '06', 'C...
# 9     685  {'GEO_ID': '0500000US06007', 'STATE': '06', 'C...
# 10    713  {'GEO_ID': '0500000US06045', 'STATE': '06', 'C...
# 11    714  {'GEO_ID': '0500000US06049', 'STATE': '06', 'C...
# 12    715  {'GEO_ID': '0500000US06051', 'STATE': '06', 'C...
# 13    716  {'GEO_ID': '0500000US06057', 'STATE': '06', 'C...
# 14    717  {'GEO_ID': '0500000US06059', 'STATE': '06', 'C...
# 15    718  {'GEO_ID': '0500000US06065', 'STATE': '06', 'C...
# 16    719  {'GEO_ID': '0500000US06069', 'STATE': '06', 'C...
# 17    720  {'GEO_ID': '0500000US06073', 'STATE': '06', 'C...
# 18    721  {'GEO_ID': '0500000US06075', 'STATE': '06', 'C...
# 19    722  {'GEO_ID': '0500000US06113', 'STATE': '06', 'C...
# 20    733  {'GEO_ID': '0500000US06081', 'STATE': '06', 'C...
# 21    734  {'GEO_ID': '0500000US06083', 'STATE': '06', 'C...
# 22    735  {'GEO_ID': '0500000US06087', 'STATE': '06', 'C...
# 23    736  {'GEO_ID': '0500000US06095', 'STATE': '06', 'C...
# 24    737  {'GEO_ID': '0500000US06101', 'STATE': '06', 'C...
# 25    738  {'GEO_ID': '0500000US06103', 'STATE': '06', 'C...
# 26    739  {'GEO_ID': '0500000US06109', 'STATE': '06', 'C...
# 27    740  {'GEO_ID': '0500000US06009', 'STATE': '06', 'C...
# 28    741  {'GEO_ID': '0500000US06013', 'STATE': '06', 'C...
# 29    742  {'GEO_ID': '0500000US06015', 'STATE': '06', 'C...
# 30    746  {'GEO_ID': '0500000US06025', 'STATE': '06', 'C...
# 31    747  {'GEO_ID': '0500000US06029', 'STATE': '06', 'C...
# 32    748  {'GEO_ID': '0500000US06031', 'STATE': '06', 'C...
# 33    749  {'GEO_ID': '0500000US06039', 'STATE': '06', 'C...
# 34   1958  {'GEO_ID': '0500000US06011', 'STATE': '06', 'C...
# 35   1959  {'GEO_ID': '0500000US06027', 'STATE': '06', 'C...
# 36   1960  {'GEO_ID': '0500000US06047', 'STATE': '06', 'C...
# 37   1961  {'GEO_ID': '0500000US06063', 'STATE': '06', 'C...
# 38   1962  {'GEO_ID': '0500000US06077', 'STATE': '06', 'C...
# 39   1963  {'GEO_ID': '0500000US06091', 'STATE': '06', 'C...
# 40   1964  {'GEO_ID': '0500000US06107', 'STATE': '06', 'C...
# 41   2002  {'GEO_ID': '0500000US06041', 'STATE': '06', 'C...
# 42   2003  {'GEO_ID': '0500000US06053', 'STATE': '06', 'C...
# 43   2004  {'GEO_ID': '0500000US06061', 'STATE': '06', 'C...
# 44   2046  {'GEO_ID': '0500000US06019', 'STATE': '06', 'C...
# 45   2047  {'GEO_ID': '0500000US06023', 'STATE': '06', 'C...
# 46   2048  {'GEO_ID': '0500000US06035', 'STATE': '06', 'C...
# 47   2049  {'GEO_ID': '0500000US06037', 'STATE': '06', 'C...
# 48   2146  {'GEO_ID': '0500000US06067', 'STATE': '06', 'C...
# 49   2147  {'GEO_ID': '0500000US06071', 'STATE': '06', 'C...
# 50   2148  {'GEO_ID': '0500000US06111', 'STATE': '06', 'C...
# 51   2248  {'GEO_ID': '0500000US06001', 'STATE': '06', 'C...
# 52   2309  {'GEO_ID': '0500000US06079', 'STATE': '06', 'C...
# 53   2310  {'GEO_ID': '0500000US06093', 'STATE': '06', 'C...
# 54   2311  {'GEO_ID': '0500000US06097', 'STATE': '06', 'C...
# 55   2312  {'GEO_ID': '0500000US06105', 'STATE': '06', 'C...
# 56   2313  {'GEO_ID': '0500000US06017', 'STATE': '06', 'C...
# 57   3141  {'GEO_ID': '0500000US06085', 'STATE': '06', 'C...
#
#                                             Geo Shape  FIPS  STATEID  \
# 0   {'type': 'Polygon', 'coordinates': [[[-120.995...  6005        6
# 1   {'type': 'Polygon', 'coordinates': [[[-122.937...  6021        6
# 2   {'type': 'Polygon', 'coordinates': [[[-122.627...  6033        6
# 3   {'type': 'Polygon', 'coordinates': [[[-120.387...  6043        6
# 4   {'type': 'Polygon', 'coordinates': [[[-122.103...  6055        6
# 5   {'type': 'Polygon', 'coordinates': [[[-123.065...  6089        6
# 6   {'type': 'Polygon', 'coordinates': [[[-120.931...  6099        6
# 7   {'type': 'Polygon', 'coordinates': [[[-121.333...  6115        6
# 8   {'type': 'Polygon', 'coordinates': [[[-120.072...  6003        6
# 9   {'type': 'Polygon', 'coordinates': [[[-121.076...  6007        6
# 10  {'type': 'Polygon', 'coordinates': [[[-122.821...  6045        6
# 11  {'type': 'Polygon', 'coordinates': [[[-121.447...  6049        6
# 12  {'type': 'Polygon', 'coordinates': [[[-119.156...  6051        6
# 13  {'type': 'Polygon', 'coordinates': [[[-121.279...  6057        6
# 14  {'type': 'Polygon', 'coordinates': [[[-118.093...  6059        6
# 15  {'type': 'Polygon', 'coordinates': [[[-117.284...  6065        6
# 16  {'type': 'Polygon', 'coordinates': [[[-121.581...  6069        6
# 17  {'type': 'Polygon', 'coordinates': [[[-116.106...  6073        6
# 18  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  6075        6
# 19  {'type': 'Polygon', 'coordinates': [[[-121.504...  6113        6
# 20  {'type': 'Polygon', 'coordinates': [[[-122.292...  6081        6
# 21  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  6083        6
# 22  {'type': 'Polygon', 'coordinates': [[[-122.015...  6087        6
# 23  {'type': 'Polygon', 'coordinates': [[[-122.088...  6095        6
# 24  {'type': 'Polygon', 'coordinates': [[[-121.484...  6101        6
# 25  {'type': 'Polygon', 'coordinates': [[[-122.934...  6103        6
# 26  {'type': 'Polygon', 'coordinates': [[[-120.652...  6109        6
# 27  {'type': 'Polygon', 'coordinates': [[[-120.652...  6009        6
# 28  {'type': 'Polygon', 'coordinates': [[[-121.910...  6013        6
# 29  {'type': 'Polygon', 'coordinates': [[[-124.065...  6015        6
# 30  {'type': 'Polygon', 'coordinates': [[[-116.103...  6025        6
# 31  {'type': 'Polygon', 'coordinates': [[[-117.667...  6029        6
# 32  {'type': 'Polygon', 'coordinates': [[[-119.905...  6031        6
# 33  {'type': 'Polygon', 'coordinates': [[[-119.733...  6039        6
# 34  {'type': 'Polygon', 'coordinates': [[[-121.908...  6011        6
# 35  {'type': 'Polygon', 'coordinates': [[[-117.832...  6027        6
# 36  {'type': 'Polygon', 'coordinates': [[[-120.931...  6047        6
# 37  {'type': 'Polygon', 'coordinates': [[[-121.076...  6063        6
# 38  {'type': 'Polygon', 'coordinates': [[[-120.926...  6077        6
# 39  {'type': 'Polygon', 'coordinates': [[[-120.001...  6091        6
# 40  {'type': 'Polygon', 'coordinates': [[[-119.214...  6107        6
# 41  {'type': 'Polygon', 'coordinates': [[[-122.490...  6041        6
# 42  {'type': 'Polygon', 'coordinates': [[[-120.213...  6053        6
# 43  {'type': 'Polygon', 'coordinates': [[[-120.005...  6061        6
# 44  {'type': 'Polygon', 'coordinates': [[[-119.573...  6019        6
# 45  {'type': 'Polygon', 'coordinates': [[[-123.544...  6023        6
# 46  {'type': 'Polygon', 'coordinates': [[[-120.001...  6035        6
# 47  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  6037        6
# 48  {'type': 'Polygon', 'coordinates': [[[-121.242...  6067        6
# 49  {'type': 'Polygon', 'coordinates': [[[-115.648...  6071        6
# 50  {'type': 'MultiPolygon', 'coordinates': [[[[-1...  6111        6
# 51  {'type': 'Polygon', 'coordinates': [[[-121.855...  6001        6
# 52  {'type': 'Polygon', 'coordinates': [[[-120.194...  6079        6
# 53  {'type': 'Polygon', 'coordinates': [[[-122.289...  6093        6
# 54  {'type': 'Polygon', 'coordinates': [[[-123.268...  6097        6
# 55  {'type': 'Polygon', 'coordinates': [[[-123.065...  6105        6
# 56  {'type': 'Polygon', 'coordinates': [[[-121.141...  6017        6
# 57  {'type': 'Polygon', 'coordinates': [[[-121.654...  6085        6
#
#              geoid
# 0   0500000US06005
# 1   0500000US06021
# 2   0500000US06033
# 3   0500000US06043
# 4   0500000US06055
# 5   0500000US06089
# 6   0500000US06099
# 7   0500000US06115
# 8   0500000US06003
# 9   0500000US06007
# 10  0500000US06045
# 11  0500000US06049
# 12  0500000US06051
# 13  0500000US06057
# 14  0500000US06059
# 15  0500000US06065
# 16  0500000US06069
# 17  0500000US06073
# 18  0500000US06075
# 19  0500000US06113
# 20  0500000US06081
# 21  0500000US06083
# 22  0500000US06087
# 23  0500000US06095
# 24  0500000US06101
# 25  0500000US06103
# 26  0500000US06109
# 27  0500000US06009
# 28  0500000US06013
# 29  0500000US06015
# 30  0500000US06025
# 31  0500000US06029
# 32  0500000US06031
# 33  0500000US06039
# 34  0500000US06011
# 35  0500000US06027
# 36  0500000US06047
# 37  0500000US06063
# 38  0500000US06077
# 39  0500000US06091
# 40  0500000US06107
# 41  0500000US06041
# 42  0500000US06053
# 43  0500000US06061
# 44  0500000US06019
# 45  0500000US06023
# 46  0500000US06035
# 47  0500000US06037
# 48  0500000US06067
# 49  0500000US06071
# 50  0500000US06111
# 51  0500000US06001
# 52  0500000US06079
# 53  0500000US06093
# 54  0500000US06097
# 55  0500000US06105
# 56  0500000US06017
# 57  0500000US06085

# %%
results_file = "etl/california-results.csv"
results_df = pd.read_csv(results_file, encoding="utf-8")
results_df.head()
# Out:
#    fips  year  winner
# 0  6001  2004       1
# 1  6003  2004       1
# 2  6005  2004      -1
# 3  6007  2004      -1
# 4  6009  2004      -1

# %%
geojson_pd.head(10)
merged_df = geojson_pd.merge(results_df, how="inner", right_on='fips', left_on='FIPS');
merged_df
# Out:
#                                             properties  \
# 0    {'GEO_ID': '0500000US06005', 'STATE': '06', 'C...
# 1    {'GEO_ID': '0500000US06005', 'STATE': '06', 'C...
# 2    {'GEO_ID': '0500000US06005', 'STATE': '06', 'C...
# 3    {'GEO_ID': '0500000US06005', 'STATE': '06', 'C...
# 4    {'GEO_ID': '0500000US06021', 'STATE': '06', 'C...
# ..                                                 ...
# 227  {'GEO_ID': '0500000US06017', 'STATE': '06', 'C...
# 228  {'GEO_ID': '0500000US06085', 'STATE': '06', 'C...
# 229  {'GEO_ID': '0500000US06085', 'STATE': '06', 'C...
# 230  {'GEO_ID': '0500000US06085', 'STATE': '06', 'C...
# 231  {'GEO_ID': '0500000US06085', 'STATE': '06', 'C...
#
#                                              Geo Shape  FIPS  STATEID  \
# 0    {'type': 'Polygon', 'coordinates': [[[-120.995...  6005        6
# 1    {'type': 'Polygon', 'coordinates': [[[-120.995...  6005        6
# 2    {'type': 'Polygon', 'coordinates': [[[-120.995...  6005        6
# 3    {'type': 'Polygon', 'coordinates': [[[-120.995...  6005        6
# 4    {'type': 'Polygon', 'coordinates': [[[-122.937...  6021        6
# ..                                                 ...   ...      ...
# 227  {'type': 'Polygon', 'coordinates': [[[-121.141...  6017        6
# 228  {'type': 'Polygon', 'coordinates': [[[-121.654...  6085        6
# 229  {'type': 'Polygon', 'coordinates': [[[-121.654...  6085        6
# 230  {'type': 'Polygon', 'coordinates': [[[-121.654...  6085        6
# 231  {'type': 'Polygon', 'coordinates': [[[-121.654...  6085        6
#
#               geoid  fips  year  winner
# 0    0500000US06005  6005  2004      -1
# 1    0500000US06005  6005  2008      -1
# 2    0500000US06005  6005  2012      -1
# 3    0500000US06005  6005  2016      -1
# 4    0500000US06021  6021  2004      -1
# ..              ...   ...   ...     ...
# 227  0500000US06017  6017  2016      -1
# 228  0500000US06085  6085  2004       1
# 229  0500000US06085  6085  2008       1
# 230  0500000US06085  6085  2012       1
# 231  0500000US06085  6085  2016       1
#
# [232 rows x 8 columns]

# %%
# create 8 new dataframes
merged_df_2004_dem = merged_df.loc[(merged_df['year'] == 2004) & (merged_df['winner'] == 1) ,:]
#merged_df_2004_rep
merged_df_2004_rep = merged_df.loc[(merged_df['year'] == 2004) & (merged_df['winner'] == -1) ,:]
#-2008
merged_df_2008_dem = merged_df.loc[(merged_df['year'] == 2008) & (merged_df['winner'] == 1) ,:]
#merged_df_2008_rep
merged_df_2008_rep = merged_df.loc[(merged_df['year'] == 2008) & (merged_df['winner'] == -1) ,:]
#2012
merged_df_2012_dem = merged_df.loc[(merged_df['year'] == 2012) & (merged_df['winner'] == 1) ,:]
#merged_df_2012_rep
merged_df_2012_rep = merged_df.loc[(merged_df['year'] == 2012) & (merged_df['winner'] == -1) ,:]
#2016
merged_df_2016_dem = merged_df.loc[(merged_df['year'] == 2016) & (merged_df['winner'] == 1) ,:]
#merged_df_2016_rep
merged_df_2016_rep = merged_df.loc[(merged_df['year'] == 2016) & (merged_df['winner'] == -1) ,:]

# %%
merged_df_2016_rep
# Out:
#                                             properties  \
# 3    {'GEO_ID': '0500000US06005', 'STATE': '06', 'C...
# 7    {'GEO_ID': '0500000US06021', 'STATE': '06', 'C...
# 15   {'GEO_ID': '0500000US06043', 'STATE': '06', 'C...
# 23   {'GEO_ID': '0500000US06089', 'STATE': '06', 'C...
# 31   {'GEO_ID': '0500000US06115', 'STATE': '06', 'C...
# 39   {'GEO_ID': '0500000US06007', 'STATE': '06', 'C...
# 47   {'GEO_ID': '0500000US06049', 'STATE': '06', 'C...
# 99   {'GEO_ID': '0500000US06101', 'STATE': '06', 'C...
# 103  {'GEO_ID': '0500000US06103', 'STATE': '06', 'C...
# 107  {'GEO_ID': '0500000US06109', 'STATE': '06', 'C...
# 111  {'GEO_ID': '0500000US06009', 'STATE': '06', 'C...
# 119  {'GEO_ID': '0500000US06015', 'STATE': '06', 'C...
# 127  {'GEO_ID': '0500000US06029', 'STATE': '06', 'C...
# 131  {'GEO_ID': '0500000US06031', 'STATE': '06', 'C...
# 135  {'GEO_ID': '0500000US06039', 'STATE': '06', 'C...
# 139  {'GEO_ID': '0500000US06011', 'STATE': '06', 'C...
# 143  {'GEO_ID': '0500000US06027', 'STATE': '06', 'C...
# 151  {'GEO_ID': '0500000US06063', 'STATE': '06', 'C...
# 159  {'GEO_ID': '0500000US06091', 'STATE': '06', 'C...
# 163  {'GEO_ID': '0500000US06107', 'STATE': '06', 'C...
# 175  {'GEO_ID': '0500000US06061', 'STATE': '06', 'C...
# 187  {'GEO_ID': '0500000US06035', 'STATE': '06', 'C...
# 215  {'GEO_ID': '0500000US06093', 'STATE': '06', 'C...
# 223  {'GEO_ID': '0500000US06105', 'STATE': '06', 'C...
# 227  {'GEO_ID': '0500000US06017', 'STATE': '06', 'C...
#
#                                              Geo Shape  FIPS  STATEID  \
# 3    {'type': 'Polygon', 'coordinates': [[[-120.995...  6005        6
# 7    {'type': 'Polygon', 'coordinates': [[[-122.937...  6021        6
# 15   {'type': 'Polygon', 'coordinates': [[[-120.387...  6043        6
# 23   {'type': 'Polygon', 'coordinates': [[[-123.065...  6089        6
# 31   {'type': 'Polygon', 'coordinates': [[[-121.333...  6115        6
# 39   {'type': 'Polygon', 'coordinates': [[[-121.076...  6007        6
# 47   {'type': 'Polygon', 'coordinates': [[[-121.447...  6049        6
# 99   {'type': 'Polygon', 'coordinates': [[[-121.484...  6101        6
# 103  {'type': 'Polygon', 'coordinates': [[[-122.934...  6103        6
# 107  {'type': 'Polygon', 'coordinates': [[[-120.652...  6109        6
# 111  {'type': 'Polygon', 'coordinates': [[[-120.652...  6009        6
# 119  {'type': 'Polygon', 'coordinates': [[[-124.065...  6015        6
# 127  {'type': 'Polygon', 'coordinates': [[[-117.667...  6029        6
# 131  {'type': 'Polygon', 'coordinates': [[[-119.905...  6031        6
# 135  {'type': 'Polygon', 'coordinates': [[[-119.733...  6039        6
# 139  {'type': 'Polygon', 'coordinates': [[[-121.908...  6011        6
# 143  {'type': 'Polygon', 'coordinates': [[[-117.832...  6027        6
# 151  {'type': 'Polygon', 'coordinates': [[[-121.076...  6063        6
# 159  {'type': 'Polygon', 'coordinates': [[[-120.001...  6091        6
# 163  {'type': 'Polygon', 'coordinates': [[[-119.214...  6107        6
# 175  {'type': 'Polygon', 'coordinates': [[[-120.005...  6061        6
# 187  {'type': 'Polygon', 'coordinates': [[[-120.001...  6035        6
# 215  {'type': 'Polygon', 'coordinates': [[[-122.289...  6093        6
# 223  {'type': 'Polygon', 'coordinates': [[[-123.065...  6105        6
# 227  {'type': 'Polygon', 'coordinates': [[[-121.141...  6017        6
#
#               geoid  fips  year  winner
# 3    0500000US06005  6005  2016      -1
# 7    0500000US06021  6021  2016      -1
# 15   0500000US06043  6043  2016      -1
# 23   0500000US06089  6089  2016      -1
# 31   0500000US06115  6115  2016      -1
# 39   0500000US06007  6007  2016      -1
# 47   0500000US06049  6049  2016      -1
# 99   0500000US06101  6101  2016      -1
# 103  0500000US06103  6103  2016      -1
# 107  0500000US06109  6109  2016      -1
# 111  0500000US06009  6009  2016      -1
# 119  0500000US06015  6015  2016      -1
# 127  0500000US06029  6029  2016      -1
# 131  0500000US06031  6031  2016      -1
# 135  0500000US06039  6039  2016      -1
# 139  0500000US06011  6011  2016      -1
# 143  0500000US06027  6027  2016      -1
# 151  0500000US06063  6063  2016      -1
# 159  0500000US06091  6091  2016      -1
# 163  0500000US06107  6107  2016      -1
# 175  0500000US06061  6061  2016      -1
# 187  0500000US06035  6035  2016      -1
# 215  0500000US06093  6093  2016      -1
# 223  0500000US06105  6105  2016      -1
# 227  0500000US06017  6017  2016      -1

# %%
# geojson_pd
# results_df
def geo_merger(results_2016):
    joined_df = pd.DataFrame();
    joined_df = geojson_pd.merge(results_2016[['FIPS','year','state_po','county','candidate','party','candidatevotes','totalvotes','percentwon']].loc[(results_2016.party == 'Republican')], how="inner", right_on='FIPS', left_on='GEOID');
    joined_df = joined_df.merge(results_2016[['FIPS','candidate','party','candidatevotes','totalvotes','percentwon']].loc[(results_2016.party == 'Democrat')], how="inner", right_on='FIPS', left_on='GEOID',suffixes=('_rep', '_dem'));
    joined_df['winner'] = np.where(joined_df['candidatevotes_rep'] > joined_df['candidatevotes_dem'], 'red',  'blue');
    return joined_df;

# %%
# results_2008 = results_df.loc[(results_df.year == 2008) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]
# results_2012 = results_df.loc[(results_df.year == 2012) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]
# results_2016 = results_df.loc[(results_df.year == 2016) & ((results_df.party == 'Republican') | (results_df.party == 'Democrat')),:]
# merged_2008 = geo_merger(results_2008);
# merged_2012 = geo_merger(results_2012);
# merged_2016 = geo_merger(results_2016);

# %%
# final_merged = pd.concat([merged_2008, merged_2012, merged_2016])

# %%
# final_merged

# %%
def df_to_geojson(df, properties):
    geojson = {'type':'FeatureCollection', 'features':[]}
    for _, row in df.iterrows():
        feature = {'type':'Feature',
                   'properties':{}
#                    'geometry':{}
                  }
        feature['geometry'] = row['Geo Shape'] #Use json.loads(row['Geo Shape']) if using the big source
        for prop in properties:
            feature['properties'][prop] = row[prop]
        geojson['features'].append(feature)
    return geojson

# %%
# properties = ['year', 'state_po', 'county', 'candidate_rep', 'party_rep', 'candidatevotes_rep', 'percentwon_rep', 'candidate_dem', 'party_dem', 'candidatevotes_dem', 'totalvotes_dem', 'percentwon_dem', 'winner']
# properties = ['year' ,'state_po', 'county', 'candidate_rep', 'party_rep', 'candidatevotes_rep', 'percentwon_rep', 'candidate_dem', 'party_dem', 'candidatevotes_dem', 'totalvotes_dem', 'percentwon_dem', 'winner']
properties = ['geoid', 'year' ,'winner']

geojson1a = df_to_geojson(merged_df_2004_dem, properties)
geojson1b = df_to_geojson(merged_df_2004_rep, properties)
geojson2a = df_to_geojson(merged_df_2008_dem, properties)
geojson2b = df_to_geojson(merged_df_2008_rep, properties)
geojson3a = df_to_geojson(merged_df_2012_dem, properties)
geojson3b = df_to_geojson(merged_df_2012_rep, properties)
geojson4a = df_to_geojson(merged_df_2016_dem, properties)
geojson4b = df_to_geojson(merged_df_2016_rep, properties)

# %%
geojson1b

# %%
json = json.dumps(geojson1b)
f = open("etl/geojson1b.json","w")
f.write(json)
f.close()

# output_filename = 'dataset.js'
# with open(output_filename, 'wb') as output_file:
#     output_file.write('var dataset = ')
#     json.dump(geojson, output_file, indent=2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-d118045713ba> in <module>
# ----> 1 json = json.dumps(geojson1b)
#       2 f = open("etl/geojson1b.json","w")
#       3 f.write(json)
#       4 f.close()
#       5
#
# AttributeError: 'str' object has no attribute 'dumps'

# %%
import json 
json = json.dumps(geojson3b)
f = open("etl/geojson3b.json","w")
f.write(json)
f.close()

# %%
geojson_pd
